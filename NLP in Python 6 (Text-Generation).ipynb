# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                  transcript full_name
# bill      [audience cheering, whistling] [emcee] Ladies ...   gabriel
# brian     ♪ [Rock] [crowd cheering] [man] let’s give a b...    oswalt
# dave      This is Dave. He tells dirty jokes for a livin...      bill
# fortune   [upbeat music plays] [audience cheering] [anno...  kathleen
# gabriel   [man] Can you please state your name? Martin M...       vir
# jim       (audience cheering, applauding) Thank you! Tha...       jim
# kathleen  [chattering] [man] Whoo! [chattering] [woman] ...   fortune
# oswalt    [“Hard to Kill” by Bleached plays] [audience c...     brian
# vir       I lost 80% of my mind. It’s very freeing. You ...      dave

# %%
# Extract only Ali Wong's text
ali_text = data.transcript.loc['vir']
ali_text[:200]
# Out:
# 'I lost 80% of my mind. It’s very freeing. You should see the look on your faces right now, by the way. Oh! Good evening, San Francisco. Are you guys excited, yeah? All right. Well, my name is Vir Das.'

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
vir_dict = markov_chain(ali_text)
vir_dict
# Out:
# {'I': ['lost',
#   'talk',
#   'just',
#   'don’t',
#   'have',
#   'can.',
#   'can',
#   'used',
#   'left',
#   'didn’t',
#   'can’t',
#   'was',
#   'went',
#   'saw',
#   'went…',
#   'went',
#   'love',
#   'believe.',
#   'promise',
#   'am',
#   'say,',
#   'know',
#   'will',
#   'grew',
#   'say',
#   'say',
#   'realize',
#   'messed',
#   'was',
#   'had',
#   'was',
#   'could',
#   'have',
#   'face',
#   'don’t',
#   'only',
#   'don’t',
#   'changed',
#   'went',
#   'went',
#   'went',
#   'went',
#   'couldn’t',
#   'realized',
#   'think',
#   'was',
#   'went',
#   'can’t',
#   'can’t',
#   'remember',
#   'told',
#   'was',
#   'can’t',
#   'had',
#   'got',
#   'think',
#   'was',
#   'don’t',
#   'lost',
#   'think',
#   'started',
#   'believe',
#   'believe',
#   'don’t',
#   'will',
#   'think',
#   'think',
#   'carried',
#   'think',
#   'think',
#   'don’t',
#   'can',
#   'believe',
#   'feel',
#   'think',
#   'wasn’t',
#   'would',
#   'will',
# ...

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(vir_dict,40)
# Out:
# 'She said, “You know, he’s still awake.” “Hainji? Really? Who hydrates in his adversity. On the money, and plagiarism, to be here, please? You know, normal Punjabi surgery happening. You know, where I talk now. And then I lost 80%.'

# %% [markdown]
# ### Assignment:
# 1. Generate sentence for other comedians also.
# 2. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.

# %%
bill_text = data.transcript.loc['bill']
bill_text[:200]
bill_dict = markov_chain(bill_text)
generate_sentence(bill_dict,20)
# Out:
# 'Goddamn smart that that happened was, in my bad, in the bar like that.” “I had too late, I’m trying.'

# %%
brian_text = data.transcript.loc['brian']
brian_text[:200]
brian_dict = markov_chain(brian_text)
generate_sentence(brian_dict,30)
# Out:
# 'Trailer with an owl go, you go up confusion. “Do you compare, when they’re talking with a staircase. So I don’t talk?” “Because they’re all your children, and he needed.'

# %%
dave_text = data.transcript.loc['dave']
dave_text[:200]
dave_dict = markov_chain(dave_text)
generate_sentence(dave_dict)
# Out:
# 'Exactly why. ‘Eww! Gross! Get over to get paid for a whole crowd banded together.'

# %%
fortune_text = data.transcript.loc['fortune']
fortune_text[:200]
fortune_dict = markov_chain(fortune_text)
generate_sentence(fortune_dict)
# Out:
# 'Cold to the one point. And I’m getting nervous. I call from this night. So.'

# %%
gabriel_text = data.transcript.loc['gabriel']
gabriel_text[:200]
gabriel_dict = markov_chain(gabriel_text)
generate_sentence(gabriel_dict)
# Out:
# 'Incredible journey. We’ve come to hear him, right? I’m so I’m, “Whoo!” And there’s a.'

# %%
jim_text = data.transcript.loc['jim']
jim_text[:200]
jim_dict = markov_chain(jim_text)
generate_sentence(jim_dict)
# Out:
# 'Do, we have young sons, you imagine how some sugar cubes that fun. Thank you!.'

# %%
oswalt_text = data.transcript.loc['oswalt']
oswalt_text[:200]
oswalt_dict = markov_chain(oswalt_text)
generate_sentence(oswalt_dict)
# Out:
# 'Wheel in 2016, then all made. The list that walked in, “Would you were two.'

# %%
kathleen_text = data.transcript.loc['kathleen']
kathleen_text[:200]
kathleen_dict = markov_chain(kathleen_text)
generate_sentence(kathleen_dict)
# Out:
# 'That– It was excited. We were half past 10:00. I know that strangers– There will.'

# %%
def generate_sentence2(chain, count=15):
    
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()
    
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    sentence += '.'
    return(sentence)
